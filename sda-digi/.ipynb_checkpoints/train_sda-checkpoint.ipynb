# %%
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

from sda.encoder_image import Encoder
from sda.img_generator import Generator
from sda.rnn_audio import RNN

from scipy import signal
from skimage import transform as tf
import numpy as np
from PIL import Image
import contextlib
import shutil
import skvideo.io as sio
import scipy.io.wavfile as wav
import ffmpeg
import face_alignment
from pydub import AudioSegment
from pydub.utils import mediainfo

import glob

# Set random seed for reproducibility
manualSeed = 999
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)

dev = torch.device("cuda:0")
# Out:
# Random Seed:  999

# %%
audio_filenames = glob.glob('/home/jarrod/dev/speech-driven-animation/data/*/*.wav')

# %%
audio_filenames
# Out:
# ['/home/jarrod/dev/speech-driven-animation/data/s3/sbag9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbba9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwc9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgbn6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brbm4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbid3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbbe1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwbs1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbwe5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lway9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swbb9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgai6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prap4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgiu9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwc7s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgbz8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brwt4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwijzn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srig8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prbc9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbws6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwbszp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgib6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgil2n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwbt4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgij6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwbr8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbbp1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbbf6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrae1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brif3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgbq9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srau2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgwc9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbip8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwwz7s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbidzn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbaczp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgbe1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swin9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwp6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbbs2n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swab6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgwr2n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prwj9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prio8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgwh6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgbm3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prwx6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrbr5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrby6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prbj5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrak6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgaa7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srihzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbwb1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbiu9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prbj4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgifzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwie4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brwg4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbal7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbwr2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swbczp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbwm4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbwk9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgav4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgiu8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgid5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prai8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwiy7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbwu5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbafzn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swau8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgas2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwic7s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrwz1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgwj4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swiu4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwbn3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgiizn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbbs5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwar4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgiz3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwp5s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swbv3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgbu3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbaa4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgia1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgiz1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbai5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbwe2n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgwx3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwbl6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwxzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbwr3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwiv8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sban1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brbm7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgij8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbav1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swwp2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwaz1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgin1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgbm1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgwu5s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbbd8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbbc5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgai4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrix9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swbv1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgby5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbiy9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgii3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbai2n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srwi1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwx1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwwmzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sria4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgwlzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwaa1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwwk5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prac6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbbn7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbiizp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwwn5s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/braf9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwwh2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrby9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prwj6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwim4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prac4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbaz5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrbr4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwbkzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbanzn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brwt5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srab1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgba9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgaf3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbig2n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swbc1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbai4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prav6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srah4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbwgzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbiu7s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swib1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbiq1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwbd7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbwh6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbar8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgib9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brbt1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwbq5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbib5s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgaq4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwwl9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrae2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbax8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbaq4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwwd8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgiq2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbbi6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwwy3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbib4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwbg8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwim3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbit2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srbozn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrwl4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brbgzn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbal6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwwf7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/briz6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwwh3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srwo4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srah3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swao4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwp4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwazzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srwizn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brwn1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwwd9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prii5s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbbi9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbws9a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbbu1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbwf9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrbe6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgia2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bril6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swwv6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgax8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbbq8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbid2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/p
.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swwv7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brbm6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prwj8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwbz3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbby2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brbs8n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgav5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prap3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbir4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgie9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrwr8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrik1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbat6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lgbf7s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgig7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgwx2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbbk5a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/prav8p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwix1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgao9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srbo3a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/swao3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pbwp7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgwo2p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgwb3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbba7s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/brwazn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lbid1s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/braf7s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgwk9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/briszn.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pripzp.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pgaq7a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sbbt9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bbir6p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lwbr9s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwaq1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/pwwk4p.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/srit6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgap1a.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bgit3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwwa6n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/sgbc4n.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/lrbr3s.wav',
#  '/home/jarrod/dev/speech-driven-animation/data/s3/bwis7s.wav',
#  ...]

# %%
# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# # Network

# %%
class getDataSample():
    def __init__(self, model_path="grid", gpu=-1):

        if model_path == "grid":
            model_path = "/home/jarrod/dev/speech-driven-animation/sda/data/grid.dat"
#         elif model_path == "timit":
#             model_path = os.path.split(__file__)[0] + "/data/timit.dat"
#         elif model_path == "crema":
#             model_path = os.path.split(__file__)[0] + "/data/crema.dat"

        if gpu < 0:
            self.device = torch.device("cpu")
            model_dict = torch.load(model_path, map_location=lambda storage, loc: storage)
            self.fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._2D, device="cpu", flip_input=False)
        else:
            self.device = torch.device("cuda:" + str(gpu))
            model_dict = torch.load(model_path, map_location=lambda storage, loc: storage.cuda(gpu))
            self.fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._2D, device="cuda:" + str(gpu),
                                                   flip_input=False)

        self.stablePntsIDs = [33, 36, 39, 42, 45]
        self.mean_face = model_dict["mean_face"]
        self.img_size = model_dict["img_size"]
        self.audio_rate = model_dict["audio_rate"]
        self.video_rate = model_dict["video_rate"]
        self.audio_feat_len = model_dict['audio_feat_len']
        self.audio_feat_samples = model_dict['audio_feat_samples']
        self.id_enc_dim = model_dict['id_enc_dim']
        self.rnn_gen_dim = model_dict['rnn_gen_dim']
        self.aud_enc_dim = model_dict['aud_enc_dim']
        # I think this is the size of the noise vector
        self.aux_latent = model_dict['aux_latent']
        # sequential noise is a boolean value
        self.sequential_noise = model_dict['sequential_noise']
        self.conversion_dict = {'s16': np.int16, 's32': np.int32}
        
        # image preprocessing
        self.img_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((self.img_size[0], self.img_size[1])),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

    def preprocess_img(self, img):
        src = self.fa.get_landmarks(img)[0][self.stablePntsIDs, :]
        dst = self.mean_face[self.stablePntsIDs, :]
        tform = tf.estimate_transform('similarity', src, dst)  # find the transformation matrix
        warped = tf.warp(img, inverse_map=tform.inverse, output_shape=self.img_size)  # wrap the frame image
        warped = warped * 255  # note output from wrap is double image (value range [0,1])
        warped = warped.astype('uint8')

        return warped

    def _cut_sequence_(self, seq, cutting_stride, pad_samples):
        pad_left = torch.zeros(pad_samples // 2, 1)
        pad_right = torch.zeros(pad_samples - pad_samples // 2, 1)

        seq = torch.cat((pad_left, seq), 0)
        seq = torch.cat((seq, pad_right), 0)

        stacked = seq.narrow(0, 0, self.audio_feat_samples).unsqueeze(0)
        iterations = (seq.size()[0] - self.audio_feat_samples) // cutting_stride + 1
        for i in range(1, iterations):
            stacked = torch.cat((stacked, seq.narrow(0, i * cutting_stride, self.audio_feat_samples).unsqueeze(0)))
        return stacked.to(self.device)

    def __call__(self, img, audio, fs=None, aligned=False):
        if isinstance(img, str):  # if we have a path then grab the image
            frm = Image.open(img)
            frm.thumbnail((400, 400))
            frame = np.array(frm)
        else:
            frame = img

        # handle aligning the face with the model's learned "mean face"
        # may also do some preprocessing
        if not aligned:
            frame = self.preprocess_img(frame)

        # if we have a path then grab the audio clip
        if isinstance(audio, str):  
            info = mediainfo(audio)
            fs = int(info['sample_rate'])
            audio = np.array(AudioSegment.from_file(audio, info['format_name']).set_channels(1).get_array_of_samples())

            if info['sample_fmt'] in self.conversion_dict:
                audio = audio.astype(self.conversion_dict[info['sample_fmt']])
            else:
                if max(audio) > np.iinfo(np.int16).max:
                    audio = audio.astype(np.int32)
                else:
                    audio = audio.astype(np.int16)

        if fs is None:
            raise AttributeError("Audio provided without specifying the rate. Specify rate or use audio file!")

        if audio.ndim > 1 and audio.shape[1] > 1:
            audio = audio[:, 0]

        max_value = np.iinfo(audio.dtype).max
        
        if fs != self.audio_rate:
            seq_length = audio.shape[0]
            speech = torch.from_numpy(
                signal.resample(audio, int(seq_length * self.audio_rate / float(fs))) / float(max_value)).float()
            speech = speech.view(-1, 1)
            
        else:
            audio = torch.from_numpy(audio / float(max_value)).float()
            speech = audio.view(-1, 1)

        # take the input image and preprocess it    
        frame = self.img_transform(frame).to(self.device)

        cutting_stride = int(self.audio_rate / float(self.video_rate))
        audio_seq_padding = self.audio_feat_samples - cutting_stride

        # Create new sequences of the audio windows
        audio_feat_seq = self._cut_sequence_(speech, cutting_stride, audio_seq_padding)
        frame = frame.unsqueeze(0)
        audio_feat_seq = audio_feat_seq.unsqueeze(0)
        audio_feat_seq_length = audio_feat_seq.size()[1]
    
        return speech, audio_feat_seq, audio_feat_seq_length, frame

# %%
class videoGenerator(nn.Module):
    def __init__(self, gpu=-1):
        
        super(videoGenerator, self).__init__()
            
        self.device = torch.device("cuda:" + str(gpu))    
        
        # size of noise vector
        self.aux_latent = 10
        self.sequential_noise = True
        self.img_size = (128,96)
        self.rnn_gen_dim = 256
        self.id_enc_dim = 128
        self.aud_enc_dim = 256
        self.audio_feat_len = 0.2
        self.audio_rate = 50000

        # audio encoder
        self.encoder = RNN(self.audio_feat_len, self.aud_enc_dim, self.rnn_gen_dim,
                           self.audio_rate, init_kernel=0.005, init_stride=0.001)
        
        

        # id_image encoder
        self.encoder_id = Encoder(self.id_enc_dim, self.img_size)
        skip_channels = list(self.encoder_id.channels)
        skip_channels.reverse()

        # generator
        self.generator = Generator(self.img_size, self.rnn_gen_dim, condition_size=self.id_enc_dim,
                                   num_gen_channels=self.encoder_id.channels[-1],
                                   skip_channels=skip_channels, aux_size=self.aux_latent,
                                   sequential_noise=self.sequential_noise)
        
    def _broadcast_elements_(self, batch, repeat_no):
        total_tensors = []
        for i in range(0, batch.size()[0]):
            total_tensors += [torch.stack(repeat_no * [batch[i]])]

        return torch.stack(total_tensors)    
    
    
    def forward(self, audio_feat_seq, audio_feat_seq_length, frame):
        
        print(frame.requires_grad)
        
        # create audio encoding from the RNN
        z = self.encoder(audio_feat_seq, [audio_feat_seq_length])  # Encoding for the motion
        
        
        print(z)
        
        
        # generate the noise input for the generator
        noise = torch.FloatTensor(1, audio_feat_seq_length, self.aux_latent).normal_(0, 0.33).to(self.device)
        
        # create encoding from image
        z_id, skips = self.encoder_id(frame, retain_intermediate=True)
        
        # the decoder is abstracted from the encoder, so pass the intermediate outputs of each
        # conv layer (the skips) to the generator (which is the decoder)
        skip_connections = []
        for skip_variable in skips:
            skip_connections.append(self._broadcast_elements_(skip_variable, z.size()[1]))
        skip_connections.reverse()

        z_id = self._broadcast_elements_(z_id, z.size()[1])
        gen_video = self.generator(z, c=z_id, aux=noise, skip=skip_connections)
        
        return gen_video

# %%
class frameDiscriminator(nn.Module):
    def __init__(self):
        super(frameDiscriminator, self).__init__()
        # number of channels = 3 id_frame, and 3 target frame
        self.nc = 3
        self.ndf = 64
        
        self.main = nn.Sequential(
            # input is (nc) x 96 x 128
            nn.Conv2d(self.nc, self.ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 48 x 64
            nn.Conv2d(self.ndf, self.ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
           
            # state size. (ndf*2) x 24 x 32
            nn.Conv2d(self.ndf * 2, self.ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*4) x 12 x 16
            nn.Conv2d(self.ndf * 4, self.ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*8) x 6 x 8
            nn.Conv2d(self.ndf * 8, self.ndf * 8, 4, 1, 0, bias=False),
        )
        self.fc1 = nn.Linear(self.ndf*8*5*3, 1)
        self.output = nn.Sigmoid()

    def forward(self, x):
        x = self.main(x)
#         print(x.shape)
        x = x.view(-1, self.ndf*8*5*3)
        x = self.fc1(x)
        
        return self.output(x)

# %%
va = getDataSample(gpu=0, model_path="grid")

# %%
aud, a1, a2, frame = va("example/male_face2.jpg", "example/hello_world.wav")

# %%
del va
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-308418a2bfab> in <module>
# ----> 1 del va
#
# NameError: name 'va' is not defined

# %%
frameD = frameDiscriminator().to(dev)
frameD.apply(weights_init)
# Out:
# frameDiscriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   )
#   (fc1): Linear(in_features=7680, out_features=1, bias=True)
#   (output): Sigmoid()
# )

# %%
ntest = videoGenerator(gpu=0).to(dev)
ntest.train()
# Out:
# videoGenerator(
#   (encoder): RNN(
#     (encoder): Encoder(
#       (cl): ModuleList(
#         (0): Conv1d(1, 16, kernel_size=(250,), stride=(50,), padding=(100,))
#         (1): Conv1d(16, 32, kernel_size=(4,), stride=(2,), padding=(1,))
#         (2): Conv1d(32, 64, kernel_size=(4,), stride=(2,), padding=(1,))
#         (3): Conv1d(64, 128, kernel_size=(4,), stride=(2,), padding=(1,))
#         (4): Conv1d(128, 256, kernel_size=(10,), stride=(5,), padding=(3,))
#         (5): Conv1d(256, 256, kernel_size=(5,), stride=(1,))
#       )
#       (activations): ModuleList(
#         (0): Sequential(
#           (0): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (2): Sequential(
#           (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (3): Sequential(
#           (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (4): Sequential(
#           (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (5): Tanh()
#       )
#     )
#     (rnn): GRU(256, 256, num_layers=2, batch_first=True)
#   )
#   (encoder_id): Encoder(
#     (cl): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (3): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (4): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (5): Sequential(
#         (0): Conv2d(1024, 128, kernel_size=(4, 3), stride=(1, 1), bias=False)
#         (1): Tanh()
#       )
#     )
#   )
#   (generator): Generator(
#     (rnn_noise): GRU(10, 10, batch_first=True)
#     (rnn_noise_squashing): Tanh()
#     (dcl): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(394, 1024, kernel_size=(4, 3), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): UnetBlock(
#         (dcl1): ConvTranspose2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (dcl2): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (activation1): Sequential(
#           (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (activation2): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#       )
#       (2): UnetBlock(
#         (dcl1): ConvTranspose2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (dcl2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (activation1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (activation2): Sequential(
#           (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#       )
#       (3): UnetBlock(
#         (dcl1): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (dcl2): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (activation1): Sequential(
#           (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (activation2): Sequential(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#       )
#       (4): UnetBlock(
#         (dcl1): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (dcl2): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (activation1): Sequential(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#         (activation2): Sequential(
#           (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#         )
#       )
#       (5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     )
#     (final_activation): Tanh()
#   )
# )

# %%
criterion = nn.BCELoss()
a1.shape
# Out:
# torch.Size([1, 71, 10000, 1])

# %%
a1 = a1.to(dev)
a1.requires_grad = True
frame = frame.to(dev)
frame.requires_grad = True
label = torch.full((71,1), 1, device=dev)

# %%
output = ntest(a1, a2, frame)
d_out = frameD(output)
err = criterion(d_out, label)
# Out:
# True
# encoder11  True
# encoder22  False
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a8c34d3a5b3b> in <module>
# ----> 1 output = ntest(a1, a2, frame)
#       2 d_out = frameD(output)
#       3 err = criterion(d_out, label)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-6-b34232d43516> in forward(self, audio_feat_seq, audio_feat_seq_length, frame)
#      46
#      47         # create audio encoding from the RNN
# ---> 48         z = self.encoder(audio_feat_seq, [audio_feat_seq_length])  # Encoding for the motion
#      49
#      50
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/dev/speech-driven-animation/sda/rnn_audio.py in forward(self, x, lengths)
#      19         x = x.reshape(-1, 1, self.audio_feat_samples)
#      20         print("encoder22 ", x.requires_grad)
# ---> 21         x = self.encoder(x1)
#      22         x = x.reshape(-1, seq_length, self.enc_code_size)
#      23         x = nn.utils.rnn.pack_padded_sequence(x, lengths, batch_first=True)
#
# NameError: name 'x1' is not defined

# %%
output

# %%
class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()
        

    def forward(self, x, lengths):
        seq_length = x.size()[1]
        print("encoder11 ", x.requires_grad)
        x = x.reshape(-1, 1, 10)
        print("encoder22 ", x.requires_grad)
        
        return x

# %%
# audio encoder
# size of noise vector
aux_latent = 10
sequential_noise = True
img_size = (128,96)
rnn_gen_dim = 256
id_enc_dim = 128
aud_enc_dim = 256
audio_feat_len = 0.2
audio_rate = 50000
# encoder = RNN(audio_feat_len, aud_enc_dim, rnn_gen_dim, audio_rate, init_kernel=0.005, init_stride=0.001)
        
encoder = RNN()

# %%
encoder = encoder.to(dev)

# %%
X = torch.ones((1,71,10000,1))
X.requires_grad = True

# %%
a1.requires_grad = True

# %%
a3 = torch.Tensor([a2])
a3.requires_grad = True
z = encoder(a1, a3)
# Out:
# encoder11  True
# encoder22  False

# %%
X.dtype
# Out:
# torch.float32

# %%
a1 *= 0

# %%
dir(a1)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__cuda_array_interface__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ilshift__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rfloordiv__',
#  '__rmul__',
#  '__rpow__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_backward_hooks',
#  '_base',
#  '_cdata',
#  '_coalesced_',
#  '_dimI',
#  '_dimV',
#  '_grad',
#  '_grad_fn',
#  '_indices',
#  '_is_view',
#  '_make_subclass',
#  '_nnz',
#  '_update_names',
#  '_values',
#  '_version',
#  'abs',
#  'abs_',
#  'acos',
#  'acos_',
#  'add',
#  'add_',
#  'addbmm',
#  'addbmm_',
#  'addcdiv',
#  'addcdiv_',
#  'addcmul',
#  'addcmul_',
#  'addmm',
#  'addmm_',
#  'addmv',
#  'addmv_',
#  'addr',
#  'addr_',
#  'align_as',
#  'align_to',
#  'all',
#  'allclose',
#  'any',
#  'apply_',
#  'argmax',
#  'argmin',
#  'argsort',
#  'as_strided',
#  'as_strided_',
#  'asin',
#  'asin_',
#  'atan',
#  'atan2',
#  'atan2_',
#  'atan_',
#  'backward',
#  'baddbmm',
#  'baddbmm_',
#  'bernoulli',
#  'bernoulli_',
#  'bfloat16',
#  'bincount',
#  'bitwise_not',
#  'bitwise_not_',
#  'bmm',
#  'bool',
#  'byte',
#  'cauchy_',
#  'ceil',
#  'ceil_',
#  'char',
#  'cholesky',
#  'cholesky_inverse',
#  'cholesky_solve',
#  'chunk',
#  'clamp',
#  'clamp_',
#  'clamp_max',
#  'clamp_max_',
#  'clamp_min',
#  'clamp_min_',
#  'clone',
#  'coalesce',
#  'contiguous',
#  'copy_',
#  'cos',
#  'cos_',
#  'cosh',
#  'cosh_',
#  'cpu',
#  'cross',
#  'cuda',
#  'cumprod',
#  'cumsum',
#  'data',
#  'data_ptr',
#  'dense_dim',
#  'dequantize',
#  'det',
#  'detach',
#  'detach_',
#  'device',
#  'diag',
#  'diag_embed',
#  'diagflat',
#  'diagonal',
#  'digamma',
#  'digamma_',
#  'dim',
#  'dist',
#  'div',
#  'div_',
#  'dot',
#  'double',
#  'dtype',
#  'eig',
#  'element_size',
#  'eq',
#  'eq_',
#  'equal',
#  'erf',
#  'erf_',
#  'erfc',
#  'erfc_',
#  'erfinv',
#  'erfinv_',
#  'exp',
#  'exp_',
#  'expand',
#  'expand_as',
#  'expm1',
#  'expm1_',
#  'exponential_',
#  'fft',
#  'fill_',
#  'fill_diagonal_',
#  'flatten',
#  'flip',
#  'float',
#  'floor',
#  'floor_',
#  'fmod',
#  'fmod_',
#  'frac',
#  'frac_',
#  'gather',
#  'ge',
#  'ge_',
#  'geometric_',
#  'geqrf',
#  'ger',
#  'get_device',
#  'grad',
#  'grad_fn',
#  'gt',
#  'gt_',
#  'half',
#  'hardshrink',
#  'has_names',
#  'histc',
#  'ifft',
#  'index_add',
#  'index_add_',
#  'index_copy',
#  'index_copy_',
#  'index_fill',
#  'index_fill_',
#  'index_put',
#  'index_put_',
#  'index_select',
#  'indices',
#  'int',
#  'int_repr',
#  'inverse',
#  'irfft',
#  'is_coalesced',
#  'is_complex',
#  'is_contiguous',
#  'is_cuda',
#  'is_distributed',
#  'is_floating_point',
#  'is_leaf',
#  'is_mkldnn',
#  'is_nonzero',
#  'is_pinned',
#  'is_quantized',
#  'is_same_size',
#  'is_set_to',
#  'is_shared',
#  'is_signed',
#  'is_sparse',
#  'isclose',
#  'item',
#  'kthvalue',
#  'layout',
#  'le',
#  'le_',
#  'lerp',
#  'lerp_',
#  'lgamma',
#  'lgamma_',
#  'log',
#  'log10',
#  'log10_',
#  'log1p',
#  'log1p_',
#  'log2',
#  'log2_',
#  'log_',
#  'log_normal_',
#  'log_softmax',
#  'logdet',
#  'logical_not',
#  'logical_not_',
#  'logical_xor',
#  'logical_xor_',
#  'logsumexp',
#  'long',
#  'lstsq',
#  'lt',
#  'lt_',
#  'lu',
#  'lu_solve',
#  'map2_',
#  'map_',
#  'masked_fill',
#  'masked_fill_',
#  'masked_scatter',
#  'masked_scatter_',
#  'masked_select',
#  'matmul',
#  'matrix_power',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'mm',
#  'mode',
#  'mul',
#  'mul_',
#  'multinomial',
#  'mv',
#  'mvlgamma',
#  'mvlgamma_',
#  'name',
#  'names',
#  'narrow',
#  'narrow_copy',
#  'ndim',
#  'ndimension',
#  'ne',
#  'ne_',
#  'neg',
#  'neg_',
#  'nelement',
#  'new',
#  'new_empty',
#  'new_full',
#  'new_ones',
#  'new_tensor',
#  'new_zeros',
#  'nonzero',
#  'norm',
#  'normal_',
#  'numel',
#  'numpy',
#  'orgqr',
#  'ormqr',
#  'output_nr',
#  'permute',
#  'pin_memory',
#  'pinverse',
#  'polygamma',
#  'polygamma_',
#  'pow',
#  'pow_',
#  'prelu',
#  'prod',
#  'put_',
#  'q_per_channel_axis',
#  'q_per_channel_scales',
#  'q_per_channel_zero_points',
#  'q_scale',
#  'q_zero_point',
#  'qr',
#  'qscheme',
#  'random_',
#  'reciprocal',
#  'reciprocal_',
#  'record_stream',
#  'refine_names',
#  'register_hook',
#  'reinforce',
#  'relu',
#  'relu_',
#  'remainder',
#  'remainder_',
#  'rename',
#  'rename_',
#  'renorm',
#  'renorm_',
#  'repeat',
#  'repeat_interleave',
#  'requires_grad',
#  'requires_grad_',
#  'reshape',
#  'reshape_as',
#  'resize',
#  'resize_',
#  'resize_as',
#  'resize_as_',
#  'retain_grad',
#  'rfft',
#  'roll',
#  'rot90',
#  'round',
#  'round_',
#  'rsqrt',
#  'rsqrt_',
#  'scatter',
#  'scatter_',
#  'scatter_add',
#  'scatter_add_',
#  'select',
#  'set_',
#  'shape',
#  'share_memory_',
#  'short',
#  'sigmoid',
#  'sigmoid_',
#  'sign',
#  'sign_',
#  'sin',
#  'sin_',
#  'sinh',
#  'sinh_',
#  'size',
#  'slogdet',
#  'smm',
#  'softmax',
#  'solve',
#  'sort',
#  'sparse_dim',
#  'sparse_mask',
#  'sparse_resize_',
#  'sparse_resize_and_clear_',
#  'split',
#  'split_with_sizes',
#  'sqrt',
#  'sqrt_',
#  'squeeze',
#  'squeeze_',
#  'sspaddmm',
#  'std',
#  'stft',
#  'storage',
#  'storage_offset',
#  'storage_type',
#  'stride',
#  'sub',
#  'sub_',
#  'sum',
#  'sum_to_size',
#  'svd',
#  'symeig',
#  't',
#  't_',
#  'take',
#  'tan',
#  'tan_',
#  'tanh',
#  'tanh_',
#  'to',
#  'to_dense',
#  'to_mkldnn',
#  'to_sparse',
#  'tolist',
#  'topk',
#  'trace',
#  'transpose',
#  'transpose_',
#  'triangular_solve',
#  'tril',
#  'tril_',
#  'triu',
#  'triu_',
#  'trunc',
#  'trunc_',
#  'type',
#  'type_as',
#  'unbind',
#  'unflatten',
#  'unfold',
#  'uniform_',
#  'unique',
#  'unique_consecutive',
#  'unsqueeze',
#  'unsqueeze_',
#  'values',
#  'var',
#  'view',
#  'view_as',
#  'where',
#  'zero_']

# %%
err.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-56-06eeb8156240> in <module>
# ----> 1 err.backward()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
